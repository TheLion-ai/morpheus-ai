# %% [markdown]
# # Preprocess UCK and Zenodo datasets for COVID-19 severity prognosis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read dataframes.

# %%
df_zenodo = pd.read_csv('../datasets/processed/auxiliary/zenodo_detection.csv')
df_uck = pd.read_csv('../datasets/processed/auxiliary/uck_detection1.csv')

# %%
print(df_zenodo['target'].value_counts())
print(df_uck['target'].value_counts())
# Out:
# 0    920
# 1    816
# Name: target, dtype: int64
# 0    16989
# 1      463
# Name: target, dtype: int64

# %% [markdown]
# Add all rows from both dataframes to a joint dataframe

# %%
df_imbalanced = df_zenodo.append(df_uck)
df_imbalanced.to_csv('../datasets/processed/imbalanced_detection2.csv')
df_imbalanced
# Out:
#        Unnamed: 0    WBC        HGB         MCV   MCHC         PLT    LYT  \
# 0               0   9.90  13.250000  100.850000  34.45  200.500000   1.20
# 1               1   9.20  14.900000   82.000000  34.90  337.000000    NaN
# 2               2   6.70  14.050000   84.300000  34.00  200.000000   0.75
# 3               3   9.70  14.500000   84.600000  34.30  209.500000   2.60
# 4               4   1.00   9.233333   98.433333  32.30   55.333333   0.50
# ...           ...    ...        ...         ...    ...         ...    ...
# 17447       30276   7.94  12.500000   90.000000  32.50  112.000000  24.70
# 17448       30163   4.66   9.100000   88.500000  35.80  133.000000  23.60
# 17449       30272  16.23  11.600000   86.900000  34.20  224.000000  14.10
# 17450       30266  12.24   7.300000   84.900000  34.10  116.000000  10.00
# 17451       30357  11.25  12.800000   85.000000  35.30  244.000000   8.70
#
#         MOT  EOT  BAT   Age  Sex  target
# 0       0.8  0.3  0.0  82.0  1.0       0
# 1       NaN  NaN  NaN  51.0  1.0       1
# 2       0.5  0.0  0.0  58.0  1.0       0
# 3       0.7  0.1  0.1  82.0  0.0       0
# 4       0.1  0.1  0.0  79.0  1.0       0
# ...     ...  ...  ...   ...  ...     ...
# 17447   8.4  0.9  0.1  73.0  1.0       0
# 17448  11.4  0.0  0.6  79.0  1.0       0
# 17449   6.7  0.1  0.2  29.0  0.0       0
# 17450   6.9  0.0  0.2  66.0  0.0       0
# 17451   2.3  0.0  0.2  88.0  0.0       0
#
# [19188 rows x 13 columns]

# %% [markdown]
# Add only as many non empty Cov- patients as their are Cov+ patients in UCK dataset. Add all rows from Zenodo.

# %%
samples_count = len(df_uck.loc[df_uck['target']==1])
samples_count
# Out:
# 463

# %%
df_uck_balanced_neg = df_uck.dropna()
df_uck_balanced_neg = df_uck_balanced_neg.loc[df_uck_balanced_neg['target']==0]
df_uck_balanced_neg = df_uck_balanced_neg.sample(n=samples_count)
df_uck_balanced_neg
df_uck_balanced_pos = df_uck.loc[df_uck['target']==1]
df_uck_balanced = df_uck_balanced_neg.append(df_uck_balanced_pos)

# %%
df_balanced = df_zenodo.append(df_uck_balanced)
df_balanced.to_csv('../datasets/processed/balanced_detection2.csv')
df_balanced
# Out:
#        Unnamed: 0    WBC        HGB         MCV   MCHC         PLT    LYT  \
# 0               0   9.90  13.250000  100.850000  34.45  200.500000   1.20
# 1               1   9.20  14.900000   82.000000  34.90  337.000000    NaN
# 2               2   6.70  14.050000   84.300000  34.00  200.000000   0.75
# 3               3   9.70  14.500000   84.600000  34.30  209.500000   2.60
# 4               4   1.00   9.233333   98.433333  32.30   55.333333   0.50
# ...           ...    ...        ...         ...    ...         ...    ...
# 17416       30199   2.10   8.800000   83.400000  30.80   70.000000  19.00
# 17419       30203  10.08   8.600000   88.400000  34.30  556.000000  14.80
# 17424       30301   1.35   8.800000   84.500000  34.40   30.000000  19.30
# 17425       30140   8.36   9.900000   93.200000  33.00  240.000000  18.90
# 17431       30294   1.07  10.600000   81.400000  32.80  124.000000  42.10
#
#         MOT  EOT  BAT   Age  Sex  target
# 0       0.8  0.3  0.0  82.0  1.0       0
# 1       NaN  NaN  NaN  51.0  1.0       1
# 2       0.5  0.0  0.0  58.0  1.0       0
# 3       0.7  0.1  0.1  82.0  0.0       0
# 4       0.1  0.1  0.0  79.0  1.0       0
# ...     ...  ...  ...   ...  ...     ...
# 17416  11.0  0.0  1.0  63.0  0.0       1
# 17419   4.2  1.0  0.6  39.0  1.0       1
# 17424  11.9  0.0  0.0  73.0  1.0       1
# 17425   6.3  1.1  0.4  77.0  0.0       1
# 17431   6.5  0.0  0.0  64.0  0.0       1
#
# [2662 rows x 13 columns]

# %%
pd.pivot_table(df_balanced, index=['target'], values=['BAT', 'EOT', 'LYT', 'MOT', 'HGB', 'MCHC', 'MCV', 'PLT', 'WBC',
       'Age', 'Sex'], aggfunc='count')
# Out:
#          Age   BAT   EOT   HGB   LYT  MCHC   MCV   MOT   PLT   Sex   WBC
# target
# 0       1329  1078  1078  1328  1078  1328  1328  1078  1328  1383  1328
# 1       1279  1219  1219  1271  1219  1271  1271  1219  1271  1279  1271

# %%
pd.pivot_table(df_imbalanced, index=['target'], values=['BAT', 'EOT', 'LYT', 'MOT', 'HGB', 'MCHC', 'MCV', 'PLT', 'WBC',
       'Age', 'Sex'], aggfunc='count')
# Out:
#           Age    BAT    EOT    HGB    LYT   MCHC    MCV    MOT    PLT    Sex  \
# target
# 0       17855  17519  17518  17854  17519  17853  17853  17518  17853  17909
# 1        1279   1219   1219   1271   1219   1271   1271   1219   1271   1279
#
#           WBC
# target
# 0       17852
# 1        1271
